# %%
# pandasインポート
import pandas as pd

# %%
matplotlib inline

# %%
ls
# Out:
# J-OFURO3_FLUXES_2002-2013.txt  Untitled1.ipynb
# Untitled.ipynb

# %%
# テキストファイルをresに読む
res = pd.read_table('J-OFURO3_FLUXES_2002-2013.txt')

# %%
# resの内容確認
res
# Out:
#      DD-MMM-YYYY      NHF     LHF    SHF    SWR  LWR
# 0    01-JAN-2002 -36.6600  105.40  8.242 -200.9  53.33
# 1    01-FEB-2002 -40.5400  103.50  7.064 -201.3  53.21
# 2    01-MAR-2002 -36.4300  103.20  5.850 -197.1  53.46
# 3    01-APR-2002 -26.7200  100.70  4.861 -184.5  52.92
# 4    01-MAY-2002 -13.2400  100.80  4.706 -170.9  52.83
# 5    01-JUN-2002   5.4580  108.30  5.632 -159.8  51.31
# 6    01-JUL-2002  -2.8040  103.50  5.670 -162.2  50.30
# 7    01-AUG-2002 -14.8000  103.30  5.444 -173.1  50.61
# 8    01-SEP-2002 -28.9800  102.00  5.837 -187.9  52.38
# 9    01-OCT-2002 -34.8600  101.80  6.777 -196.0  53.72
# 10   01-NOV-2002 -30.7300  107.60  7.215 -196.9  52.72
# 11   01-DEC-2002 -32.3400  106.30  9.223 -199.3  53.10
# 12   01-JAN-2003 -31.8600  108.70  8.886 -200.8  53.38
# 13   01-FEB-2003 -37.5300  105.00  8.234 -202.1  53.47
# 14   01-MAR-2003 -35.1600  102.30  6.948 -197.5  54.45
# 15   01-APR-2003 -23.2800  101.70  5.801 -183.4  52.94
# ...

# %%
# NHFだけのシリーズ
res.NHF
# Out:
# 0     -36.6600
# 1     -40.5400
# 2     -36.4300
# 3     -26.7200
# 4     -13.2400
# 5       5.4580
# 6      -2.8040
# 7     -14.8000
# 8     -28.9800
# 9     -34.8600
# 10    -30.7300
# 11    -32.3400
# 12    -31.8600
# 13    -37.5300
# 14    -35.1600
# 15    -23.2800
# 16     -8.2130
# 17     -0.2258
# 18     -0.3927
# 19    -16.2800
# 20    -27.1400
# 21    -34.8100
# 22    -34.3700
# 23    -30.7800
# 24    -35.3500
# 25    -34.6400
# 26    -29.3500
# 27    -24.7500
# 28     -7.0680
# 29      5.9230
#         ...
# 114     3.0620
# 115   -13.0900
# 116   -26.4000
# 117   -34.6500
# 118   -34.3800
# 119   -33.0700
# 120   -38.8200
# 121   -40.1900
# 122   -34.5300
# 123   -24.2600
# 124    -7.2450
# 125     0.6807
# 126    -7.1470
# 127   -19.6400
# 128   -31.5500
# 129   -43.1000
# 130   -42.3900
# 131   -40.0400
# 132   -35.5800
# 133   -40.0200
# 134   -38.7500
# 135   -25.0600
# 136    -9.1640
# 137     1.8030
# 138    -2.9910
# 139   -18.1500
# 140   -27.2400
# 141   -35.5200
# ...

# %%
#同じくLHFだけのシリーズ
res.LHF
# Out:
# 0      105.40
# 1      103.50
# 2      103.20
# 3      100.70
# 4      100.80
# 5      108.30
# 6      103.50
# 7      103.30
# 8      102.00
# 9      101.80
# 10     107.60
# 11     106.30
# 12     108.70
# 13     105.00
# 14     102.30
# 15     101.70
# 16     102.30
# 17     102.20
# 18     105.50
# 19     101.80
# 20     103.20
# 21     103.00
# 22     104.80
# 23     108.00
# 24     104.90
# 25     105.90
# 26     105.30
# 27     101.80
# 28     102.70
# 29     107.70
#         ...
# 114    106.00
# 115    103.00
# 116    102.50
# 117    102.10
# 118    106.10
# 119    106.50
# 120    104.30
# 121    103.30
# 122    103.30
# 123    101.80
# 124    103.60
# 125    105.00
# 126     98.24
# 127     97.51
# 128     97.92
# 129     95.61
# 130     97.07
# 131     98.99
# 132    108.70
# 133    105.30
# 134    100.70
# 135    101.30
# 136    103.50
# 137    107.20
# 138    106.50
# 139    103.80
# 140    106.20
# 141    104.80
# 142    107.40
# 143    106.00
# ...

# %%
# numpyをnpとしてインポート
import numpy as np

# %%
# 平均値の計算
ave = np.average(res.NHF)
ave
# Out:
# -23.255114583333334

# %%
# 偏差の計算
anomaly = res.NHF - ave
anomaly

# %%
anomaly.size
# Out:
# 144

# %%
# 偏差のプロット
anomaly.plot()

# %%
# NHFのプロット
res.NHF.plot()

# %%
# LHFのプロット
res.LHF.plot()
