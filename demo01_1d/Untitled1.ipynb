# %%
from pandas import Series, DataFrame
import pandas as pd

# %%
matplotlib inline

# %%
# !ls
# Out:
# J-OFURO3_FLUXES_2002-2013.txt Untitled1.ipynb
# Untitled.ipynb

# %%
res = pd.read_table('J-OFURO3_FLUXES_2002-2013.txt')

# %%
res
# Out:
#      DD-MMM-YYYY      NHF     LHF    SHF    SWR  LWR
# 0    01-JAN-2002 -36.6600  105.40  8.242 -200.9  53.33
# 1    01-FEB-2002 -40.5400  103.50  7.064 -201.3  53.21
# 2    01-MAR-2002 -36.4300  103.20  5.850 -197.1  53.46
# 3    01-APR-2002 -26.7200  100.70  4.861 -184.5  52.92
# 4    01-MAY-2002 -13.2400  100.80  4.706 -170.9  52.83
# 5    01-JUN-2002   5.4580  108.30  5.632 -159.8  51.31
# 6    01-JUL-2002  -2.8040  103.50  5.670 -162.2  50.30
# 7    01-AUG-2002 -14.8000  103.30  5.444 -173.1  50.61
# 8    01-SEP-2002 -28.9800  102.00  5.837 -187.9  52.38
# 9    01-OCT-2002 -34.8600  101.80  6.777 -196.0  53.72
# 10   01-NOV-2002 -30.7300  107.60  7.215 -196.9  52.72
# 11   01-DEC-2002 -32.3400  106.30  9.223 -199.3  53.10
# 12   01-JAN-2003 -31.8600  108.70  8.886 -200.8  53.38
# 13   01-FEB-2003 -37.5300  105.00  8.234 -202.1  53.47
# 14   01-MAR-2003 -35.1600  102.30  6.948 -197.5  54.45
# 15   01-APR-2003 -23.2800  101.70  5.801 -183.4  52.94
# ...

# %%
res.plot()

# %%
pd.res.plot()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-c1fd94a3a317> in <module>()
# ----> 1 pd.res.plot()
#
# AttributeError: module 'pandas' has no attribute 'res'

# %%
res.plot()

# %%
res.plot()  #全変数

# %%
ls
# Out:
# J-OFURO3_FLUXES_2002-2013.txt  Untitled1.ipynb
# Untitled.ipynb

# %%
import numpy as np

# %%
np.average(res.NHF)
# Out:
# -23.255114583333334

# %%
ave = np.average(res.NHF)

# %%
ave
# Out:
# -23.255114583333334

# %%
anomaly = res.NHF - ave

# %%
anomaly
# Out:
# 0     -13.404885
# 1     -17.284885
# 2     -13.174885
# 3      -3.464885
# 4      10.015115
# 5      28.713115
# 6      20.451115
# 7       8.455115
# 8      -5.724885
# 9     -11.604885
# 10     -7.474885
# 11     -9.084885
# 12     -8.604885
# 13    -14.274885
# 14    -11.904885
# 15     -0.024885
# 16     15.042115
# 17     23.029315
# 18     22.862415
# 19      6.975115
# 20     -3.884885
# 21    -11.554885
# 22    -11.114885
# 23     -7.524885
# 24    -12.094885
# 25    -11.384885
# 26     -6.094885
# 27     -1.494885
# 28     16.187115
# 29     29.178115
#          ...
# 114    26.317115
# 115    10.165115
# 116    -3.144885
# 117   -11.394885
# 118   -11.124885
# 119    -9.814885
# 120   -15.564885
# 121   -16.934885
# 122   -11.274885
# 123    -1.004885
# 124    16.010115
# 125    23.935815
# 126    16.108115
# 127     3.615115
# 128    -8.294885
# 129   -19.844885
# 130   -19.134885
# 131   -16.784885
# 132   -12.324885
# 133   -16.764885
# 134   -15.494885
# ...

# %%
plot(anomaly)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-295cbff05076> in <module>()
# ----> 1 plot(anomaly)
#
# NameError: name 'plot' is not defined

# %%
plt.plot(anomaly)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-a5f2395008d5> in <module>()
# ----> 1 plt.plot(anomaly)
#
# NameError: name 'plt' is not defined

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(anomaly)

# %%
res
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-41a0db25bac4> in <module>()
# ----> 1 res
#
# NameError: name 'res' is not defined

# %%
res = pd.read_table('J-OFURO3_FLUXES_2002-2013.txt')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-68a7ba8d92f6> in <module>()
# ----> 1 res = pd.read_table('J-OFURO3_FLUXES_2002-2013.txt')
#
# NameError: name 'pd' is not defined

# %%
from pandas import Series, DataFrame
import pandas as pd

# %%
matplotlib inline

# %%
res = pd.read_table('J-OFURO3_FLUXES_2002-2013.txt')

# %%
res
# Out:
#      DD-MMM-YYYY      NHF     LHF    SHF    SWR  LWR
# 0    01-JAN-2002 -36.6600  105.40  8.242 -200.9  53.33
# 1    01-FEB-2002 -40.5400  103.50  7.064 -201.3  53.21
# 2    01-MAR-2002 -36.4300  103.20  5.850 -197.1  53.46
# 3    01-APR-2002 -26.7200  100.70  4.861 -184.5  52.92
# 4    01-MAY-2002 -13.2400  100.80  4.706 -170.9  52.83
# 5    01-JUN-2002   5.4580  108.30  5.632 -159.8  51.31
# 6    01-JUL-2002  -2.8040  103.50  5.670 -162.2  50.30
# 7    01-AUG-2002 -14.8000  103.30  5.444 -173.1  50.61
# 8    01-SEP-2002 -28.9800  102.00  5.837 -187.9  52.38
# 9    01-OCT-2002 -34.8600  101.80  6.777 -196.0  53.72
# 10   01-NOV-2002 -30.7300  107.60  7.215 -196.9  52.72
# 11   01-DEC-2002 -32.3400  106.30  9.223 -199.3  53.10
# 12   01-JAN-2003 -31.8600  108.70  8.886 -200.8  53.38
# 13   01-FEB-2003 -37.5300  105.00  8.234 -202.1  53.47
# 14   01-MAR-2003 -35.1600  102.30  6.948 -197.5  54.45
# 15   01-APR-2003 -23.2800  101.70  5.801 -183.4  52.94
# ...

# %%
res  #確認
# Out:
#      DD-MMM-YYYY      NHF     LHF    SHF    SWR  LWR
# 0    01-JAN-2002 -36.6600  105.40  8.242 -200.9  53.33
# 1    01-FEB-2002 -40.5400  103.50  7.064 -201.3  53.21
# 2    01-MAR-2002 -36.4300  103.20  5.850 -197.1  53.46
# 3    01-APR-2002 -26.7200  100.70  4.861 -184.5  52.92
# 4    01-MAY-2002 -13.2400  100.80  4.706 -170.9  52.83
# 5    01-JUN-2002   5.4580  108.30  5.632 -159.8  51.31
# 6    01-JUL-2002  -2.8040  103.50  5.670 -162.2  50.30
# 7    01-AUG-2002 -14.8000  103.30  5.444 -173.1  50.61
# 8    01-SEP-2002 -28.9800  102.00  5.837 -187.9  52.38
# 9    01-OCT-2002 -34.8600  101.80  6.777 -196.0  53.72
# 10   01-NOV-2002 -30.7300  107.60  7.215 -196.9  52.72
# 11   01-DEC-2002 -32.3400  106.30  9.223 -199.3  53.10
# 12   01-JAN-2003 -31.8600  108.70  8.886 -200.8  53.38
# 13   01-FEB-2003 -37.5300  105.00  8.234 -202.1  53.47
# 14   01-MAR-2003 -35.1600  102.30  6.948 -197.5  54.45
# 15   01-APR-2003 -23.2800  101.70  5.801 -183.4  52.94
# ...

# %%
res = pd.read_table('J-OFURO3_FLUXES_2002-2013.txt' index_col=0)
# Out:
#   File "<ipython-input-9-7b3f8898b56e>", line 1
#     res = pd.read_table('J-OFURO3_FLUXES_2002-2013.txt’, index_col=0)
#                                                                      ^
# SyntaxError: EOL while scanning string literal

# %%
res = pd.read_table('J-OFURO3_FLUXES_2002-2013.txt', index_col=0)

# %%
res
# Out:
#      DD-MMM-YYYY      NHF     LHF    SHF    SWR  LWR
# 0    01-JAN-2002 -36.6600  105.40  8.242 -200.9  53.33
# 1    01-FEB-2002 -40.5400  103.50  7.064 -201.3  53.21
# 2    01-MAR-2002 -36.4300  103.20  5.850 -197.1  53.46
# 3    01-APR-2002 -26.7200  100.70  4.861 -184.5  52.92
# 4    01-MAY-2002 -13.2400  100.80  4.706 -170.9  52.83
# 5    01-JUN-2002   5.4580  108.30  5.632 -159.8  51.31
# 6    01-JUL-2002  -2.8040  103.50  5.670 -162.2  50.30
# 7    01-AUG-2002 -14.8000  103.30  5.444 -173.1  50.61
# 8    01-SEP-2002 -28.9800  102.00  5.837 -187.9  52.38
# 9    01-OCT-2002 -34.8600  101.80  6.777 -196.0  53.72
# 10   01-NOV-2002 -30.7300  107.60  7.215 -196.9  52.72
# 11   01-DEC-2002 -32.3400  106.30  9.223 -199.3  53.10
# 12   01-JAN-2003 -31.8600  108.70  8.886 -200.8  53.38
# 13   01-FEB-2003 -37.5300  105.00  8.234 -202.1  53.47
# 14   01-MAR-2003 -35.1600  102.30  6.948 -197.5  54.45
# 15   01-APR-2003 -23.2800  101.70  5.801 -183.4  52.94
# ...

# %%
res
# Out:
#                  NHF     LHF    SHF    SWR  LWR
# DD-MMM-YYYY
# 01-JAN-2002 -36.6600  105.40  8.242 -200.9  53.33
# 01-FEB-2002 -40.5400  103.50  7.064 -201.3  53.21
# 01-MAR-2002 -36.4300  103.20  5.850 -197.1  53.46
# 01-APR-2002 -26.7200  100.70  4.861 -184.5  52.92
# 01-MAY-2002 -13.2400  100.80  4.706 -170.9  52.83
# 01-JUN-2002   5.4580  108.30  5.632 -159.8  51.31
# 01-JUL-2002  -2.8040  103.50  5.670 -162.2  50.30
# 01-AUG-2002 -14.8000  103.30  5.444 -173.1  50.61
# 01-SEP-2002 -28.9800  102.00  5.837 -187.9  52.38
# 01-OCT-2002 -34.8600  101.80  6.777 -196.0  53.72
# 01-NOV-2002 -30.7300  107.60  7.215 -196.9  52.72
# 01-DEC-2002 -32.3400  106.30  9.223 -199.3  53.10
# 01-JAN-2003 -31.8600  108.70  8.886 -200.8  53.38
# 01-FEB-2003 -37.5300  105.00  8.234 -202.1  53.47
# 01-MAR-2003 -35.1600  102.30  6.948 -197.5  54.45
# 01-APR-2003 -23.2800  101.70  5.801 -183.4  52.94
# 01-MAY-2003  -8.2130  102.30  5.085 -167.3  51.67
# 01-JUN-2003  -0.2258  102.20  6.017 -161.1  52.54
# ...

# %%
res = pd.read_table('J-OFURO3_FLUXES_2002-2013.txt', index_col=0)
# Out:
#   File "<ipython-input-14-fa897d586c45>", line 4
#     res = pd.read_table('J-OFURO3_FLUXES_2002-2013.txt’, index_col=0)
#                                                                      ^
# SyntaxError: EOL while scanning string literal

# %%
res = pd.read_table('J-OFURO3_FLUXES_2002-2013.txt', index_col=0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-d5fd97d838a4> in <module>()
# ----> 1 res = pd.read_table('J-OFURO3_FLUXES_2002-2013.txt', index_col=0)
#
# NameError: name 'pd' is not defined

# %%
res
# Out:
#                  NHF     LHF    SHF    SWR  LWR
# DD-MMM-YYYY
# 01-JAN-2002 -36.6600  105.40  8.242 -200.9  53.33
# 01-FEB-2002 -40.5400  103.50  7.064 -201.3  53.21
# 01-MAR-2002 -36.4300  103.20  5.850 -197.1  53.46
# 01-APR-2002 -26.7200  100.70  4.861 -184.5  52.92
# 01-MAY-2002 -13.2400  100.80  4.706 -170.9  52.83
# 01-JUN-2002   5.4580  108.30  5.632 -159.8  51.31
# 01-JUL-2002  -2.8040  103.50  5.670 -162.2  50.30
# 01-AUG-2002 -14.8000  103.30  5.444 -173.1  50.61
# 01-SEP-2002 -28.9800  102.00  5.837 -187.9  52.38
# 01-OCT-2002 -34.8600  101.80  6.777 -196.0  53.72
# 01-NOV-2002 -30.7300  107.60  7.215 -196.9  52.72
# 01-DEC-2002 -32.3400  106.30  9.223 -199.3  53.10
# 01-JAN-2003 -31.8600  108.70  8.886 -200.8  53.38
# 01-FEB-2003 -37.5300  105.00  8.234 -202.1  53.47
# 01-MAR-2003 -35.1600  102.30  6.948 -197.5  54.45
# 01-APR-2003 -23.2800  101.70  5.801 -183.4  52.94
# 01-MAY-2003  -8.2130  102.30  5.085 -167.3  51.67
# 01-JUN-2003  -0.2258  102.20  6.017 -161.1  52.54
# ...

# %%
pd.plot(res)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-e2d3e6756e3c> in <module>()
# ----> 1 pd.plot(res)
#
# AttributeError: module 'pandas' has no attribute 'plot'

# %%
res.plot()

# %%
from pandas import Series, DataFrame
import pandas as pd

# %%
matplotlib inline

# %%
res = pd.read_table('J-OFURO3_FLUXES_2002-2013.txt')

# %%
res
# Out:
#      DD-MMM-YYYY      NHF     LHF    SHF    SWR  LWR
# 0    01-JAN-2002 -36.6600  105.40  8.242 -200.9  53.33
# 1    01-FEB-2002 -40.5400  103.50  7.064 -201.3  53.21
# 2    01-MAR-2002 -36.4300  103.20  5.850 -197.1  53.46
# 3    01-APR-2002 -26.7200  100.70  4.861 -184.5  52.92
# 4    01-MAY-2002 -13.2400  100.80  4.706 -170.9  52.83
# 5    01-JUN-2002   5.4580  108.30  5.632 -159.8  51.31
# 6    01-JUL-2002  -2.8040  103.50  5.670 -162.2  50.30
# 7    01-AUG-2002 -14.8000  103.30  5.444 -173.1  50.61
# 8    01-SEP-2002 -28.9800  102.00  5.837 -187.9  52.38
# 9    01-OCT-2002 -34.8600  101.80  6.777 -196.0  53.72
# 10   01-NOV-2002 -30.7300  107.60  7.215 -196.9  52.72
# 11   01-DEC-2002 -32.3400  106.30  9.223 -199.3  53.10
# 12   01-JAN-2003 -31.8600  108.70  8.886 -200.8  53.38
# 13   01-FEB-2003 -37.5300  105.00  8.234 -202.1  53.47
# 14   01-MAR-2003 -35.1600  102.30  6.948 -197.5  54.45
# 15   01-APR-2003 -23.2800  101.70  5.801 -183.4  52.94
# ...

# %%
res.plot()
